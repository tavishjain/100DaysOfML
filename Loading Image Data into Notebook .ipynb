# %% [markdown]
# # Loading Image Data
#
# So far we've been working with fairly artificial datasets that you wouldn't typically be using in real projects. Instead, you'll likely be dealing with full-sized images like you'd get from smart phone cameras. In this notebook, we'll look at how to load images and use them to train neural networks.
#
# We'll be using a [dataset of cat and dog photos](https://www.kaggle.com/c/dogs-vs-cats) available from Kaggle. Here are a couple example images:
#
# <img src='assets/dog_cat.png'>
#
# We'll use this dataset to train a neural network that can differentiate between cats and dogs. These days it doesn't seem like a big accomplishment, but five years ago it was a serious challenge for computer vision systems.

# %%
# # Mounting Google Drive onto Colab
# from google.colab import drive
# drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
# !pip install -U -q kaggle
# !mkdir -p /content/sample_data/kaggle
# Out:
#     100% |████████████████████████████████| 61kB 5.3MB/s
#   Building wheel for kaggle (setup.py) ... done

# %%
# from google.colab import files
# files.upload()
# Out:
#      <input type="file" id="files-3aaf6606-729b-43eb-acf3-0860fbcbde99" name="files[]" multiple disabled />
#      <output id="result-3aaf6606-729b-43eb-acf3-0860fbcbde99">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle.json
# {'kaggle.json': b'{"username":"tavishjain","key":"21a0804013d3776055135a0f8a5ab5ec"}'}

# %%
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/

# !chmod 600 ~/.kaggle/kaggle.json

# %%
# !kaggle datasets download -d lucassj/dogs-vs-cats-train-validadion-and-evaluation.zip

# %%
# !unzip dogs-vs-cats-train-validadion-and-evaluation.zip
# Out:
# Archive:  dogs-vs-cats-train-validadion-and-evaluation.zip
#    creating: evaluation/
#    creating: evaluation/cat/
#   inflating: evaluation/cat/10.jpg
#   inflating: evaluation/cat/100.jpg
#   inflating: evaluation/cat/101.jpg
#   inflating: evaluation/cat/103.jpg
#   inflating: evaluation/cat/104.jpg
#   inflating: evaluation/cat/107.jpg
#   inflating: evaluation/cat/108.jpg
#   inflating: evaluation/cat/11.jpg
#   inflating: evaluation/cat/114.jpg
#   inflating: evaluation/cat/115.jpg
#   inflating: evaluation/cat/116.jpg
#   inflating: evaluation/cat/117.jpg
#   inflating: evaluation/cat/120.jpg
#   inflating: evaluation/cat/121.jpg
#   inflating: evaluation/cat/122.jpg
#   inflating: evaluation/cat/123.jpg
#   inflating: evaluation/cat/124.jpg
#   inflating: evaluation/cat/125.jpg
#   inflating: evaluation/cat/128.jpg
#   inflating: evaluation/cat/129.jpg
#   inflating: evaluation/cat/13.jpg
#   inflating: evaluation/cat/133.jpg
#   inflating: evaluation/cat/134.jpg
#   inflating: evaluation/cat/135.jpg
#   inflating: evaluation/cat/136.jpg
#   inflating: evaluation/cat/139.jpg
#   inflating: evaluation/cat/14.jpg
#   inflating: evaluation/cat/140.jpg
#   inflating: evaluation/cat/141.jpg
#   inflating: evaluation/cat/144.jpg
#   inflating: evaluation/cat/145.jpg
#   inflating: evaluation/cat/148.jpg
#   inflating: evaluation/cat/149.jpg
#   inflating: evaluation/cat/15.jpg
#   inflating: evaluation/cat/150.jpg
#   inflating: evaluation/cat/152.jpg
#   inflating: evaluation/cat/153.jpg
#   inflating: evaluation/cat/154.jpg
#   inflating: evaluation/cat/156.jpg
#   inflating: evaluation/cat/157.jpg
#   inflating: evaluation/cat/16.jpg
#   inflating: evaluation/cat/161.jpg
#   inflating: evaluation/cat/162.jpg
#   inflating: evaluation/cat/163.jpg
#   inflating: evaluation/cat/165.jpg
#   inflating: evaluation/cat/166.jpg
#   inflating: evaluation/cat/168.jpg
#   inflating: evaluation/cat/169.jpg
#   inflating: evaluation/cat/170.jpg
#   inflating: evaluation/cat/171.jpg
#   inflating: evaluation/cat/174.jpg
#   inflating: evaluation/cat/180.jpg
#   inflating: evaluation/cat/183.jpg
#   inflating: evaluation/cat/184.jpg
#   inflating: evaluation/cat/185.jpg
#   inflating: evaluation/cat/187.jpg
#   inflating: evaluation/cat/188.jpg
#   inflating: evaluation/cat/19.jpg
#   inflating: evaluation/cat/20.jpg
#   inflating: evaluation/cat/22.jpg
#   inflating: evaluation/cat/25.jpg
#   inflating: evaluation/cat/28.jpg
#   inflating: evaluation/cat/29.jpg
#   inflating: evaluation/cat/34.jpg
#   inflating: evaluation/cat/35.jpg
#   inflating: evaluation/cat/36.jpg
#   inflating: evaluation/cat/37.jpg
#   inflating: evaluation/cat/38.jpg
#   inflating: evaluation/cat/40.jpg
#   inflating: evaluation/cat/45.jpg
#   inflating: evaluation/cat/47.jpg
#   inflating: evaluation/cat/5.jpg
#   inflating: evaluation/cat/50.jpg
#   inflating: evaluation/cat/51.jpg
#   inflating: evaluation/cat/52.jpg
#   inflating: evaluation/cat/53.jpg
#   inflating: evaluation/cat/54.jpg
#   inflating: evaluation/cat/55.jpg
#   inflating: evaluation/cat/58.jpg
#   inflating: evaluation/cat/6.jpg
#   inflating: evaluation/cat/60.jpg
#   inflating: evaluation/cat/61.jpg
#   inflating: evaluation/cat/63.jpg
#   inflating: evaluation/cat/64.jpg
#   inflating: evaluation/cat/68.jpg
#   inflating: evaluation/cat/7.jpg
#   inflating: evaluation/cat/75.jpg
#   inflating: evaluation/cat/8.jpg
#   inflating: evaluation/cat/80.jpg
#   inflating: evaluation/cat/81.jpg
#   inflating: evaluation/cat/82.jpg
#   inflating: evaluation/cat/84.jpg
#   inflating: evaluation/cat/89.jpg
#   inflating: evaluation/cat/9.jpg
#   inflating: evaluation/cat/90.jpg
#   inflating: evaluation/cat/91.jpg
#   inflating: evaluation/cat/92.jpg
#   inflating: evaluation/cat/93.jpg
#   inflating: evaluation/cat/96.jpg
#   inflating: evaluation/cat/99.jpg
#    creating: evaluation/dog/
#   inflating: evaluation/dog/1.jpg
#   inflating: evaluation/dog/102.jpg
#   inflating: evaluation/dog/105.jpg
#   inflating: evaluation/dog/106.jpg
#   inflating: evaluation/dog/109.jpg
#   inflating: evaluation/dog/110.jpg
#   inflating: evaluation/dog/111.jpg
#   inflating: evaluation/dog/112.jpg
#   inflating: evaluation/dog/113.jpg
#   inflating: evaluation/dog/118.jpg
#   inflating: evaluation/dog/119.jpg
#   inflating: evaluation/dog/12.jpg
#   inflating: evaluation/dog/126.jpg
#   inflating: evaluation/dog/127.jpg
#   inflating: evaluation/dog/130.jpg
#   inflating: evaluation/dog/131.jpg
#   inflating: evaluation/dog/132.jpg
#   inflating: evaluation/dog/137.jpg
#   inflating: evaluation/dog/138.jpg
#   inflating: evaluation/dog/142.jpg
#   inflating: evaluation/dog/143.jpg
#   inflating: evaluation/dog/146.jpg
#   inflating: evaluation/dog/147.jpg
#   inflating: evaluation/dog/151.jpg
#   inflating: evaluation/dog/155.jpg
#   inflating: evaluation/dog/158.jpg
#   inflating: evaluation/dog/159.jpg
#   inflating: evaluation/dog/160.jpg
#   inflating: evaluation/dog/164.jpg
#   inflating: evaluation/dog/167.jpg
#   inflating: evaluation/dog/17.jpg
#   inflating: evaluation/dog/172.jpg
#   inflating: evaluation/dog/173.jpg
#   inflating: evaluation/dog/175.jpg
#   inflating: evaluation/dog/176.jpg
#   inflating: evaluation/dog/177.jpg
#   inflating: evaluation/dog/178.jpg
#   inflating: evaluation/dog/179.jpg
#   inflating: evaluation/dog/18.jpg
#   inflating: evaluation/dog/181.jpg
#   inflating: evaluation/dog/182.jpg
#   inflating: evaluation/dog/190.jpg
#   inflating: evaluation/dog/195.jpg
#   inflating: evaluation/dog/196.jpg
#   inflating: evaluation/dog/197.jpg
#   inflating: evaluation/dog/199.jpg
#   inflating: evaluation/dog/2.jpg
#   inflating: evaluation/dog/200.jpg
#   inflating: evaluation/dog/201.jpg
#   inflating: evaluation/dog/203.jpg
#   inflating: evaluation/dog/204.jpg
#   inflating: evaluation/dog/207.jpg
#   inflating: evaluation/dog/21.jpg
#   inflating: evaluation/dog/211.jpg
#   inflating: evaluation/dog/212.jpg
#   inflating: evaluation/dog/214.jpg
#   inflating: evaluation/dog/23.jpg
#   inflating: evaluation/dog/24.jpg
#   inflating: evaluation/dog/26.jpg
#   inflating: evaluation/dog/27.jpg
#   inflating: evaluation/dog/3.jpg
#   inflating: evaluation/dog/30.jpg
#   inflating: evaluation/dog/31.jpg
#   inflating: evaluation/dog/32.jpg
#   inflating: evaluation/dog/33.jpg
#   inflating: evaluation/dog/39.jpg
#   inflating: evaluation/dog/4.jpg
#   inflating: evaluation/dog/41.jpg
#   inflating: evaluation/dog/42.jpg
#   inflating: evaluation/dog/43.jpg
#   inflating: evaluation/dog/44.jpg
#   inflating: evaluation/dog/46.jpg
#   inflating: evaluation/dog/48.jpg
#   inflating: evaluation/dog/49.jpg
#   inflating: evaluation/dog/56.jpg
#   inflating: evaluation/dog/57.jpg
#   inflating: evaluation/dog/59.jpg
#   inflating: evaluation/dog/62.jpg
#   inflating: evaluation/dog/65.jpg
#   inflating: evaluation/dog/66.jpg
#   inflating: evaluation/dog/67.jpg
#   inflating: evaluation/dog/69.jpg
#   inflating: evaluation/dog/70.jpg
#   inflating: evaluation/dog/71.jpg
#   inflating: evaluation/dog/72.jpg
#   inflating: evaluation/dog/73.jpg
#   inflating: evaluation/dog/74.jpg
#   inflating: evaluation/dog/76.jpg
#   inflating: evaluation/dog/77.jpg
#   inflating: evaluation/dog/78.jpg
#   inflating: evaluation/dog/79.jpg
#   inflating: evaluation/dog/83.jpg
#   inflating: evaluation/dog/85.jpg
#   inflating: evaluation/dog/86.jpg
#   inflating: evaluation/dog/87.jpg
#   inflating: evaluation/dog/88.jpg
#   inflating: evaluation/dog/94.jpg
#   inflating: evaluation/dog/95.jpg
#   inflating: evaluation/dog/97.jpg
#   inflating: evaluation/dog/98.jpg
#    creating: train/
#    creating: train/dog/
#   inflating: train/dog/dog.1033.jpg
#   inflating: train/dog/dog.1044.jpg
#   inflating: train/dog/dog.106.jpg
#   inflating: train/dog/dog.1066.jpg
#   inflating: train/dog/dog.1071.jpg
#   inflating: train/dog/dog.1072.jpg
#   inflating: train/dog/dog.1079.jpg
#   inflating: train/dog/dog.1086.jpg
#   inflating: train/dog/dog.1097.jpg
#   inflating: train/dog/dog.1113.jpg
#   inflating: train/dog/dog.1116.jpg
#   inflating: train/dog/dog.1120.jpg
#   inflating: train/dog/dog.1121.jpg
#   inflating: train/dog/dog.1126.jpg
#   inflating: train/dog/dog.1129.jpg
#   inflating: train/dog/dog.113.jpg
#   inflating: train/dog/dog.1132.jpg
#   inflating: train/dog/dog.1143.jpg
#   inflating: train/dog/dog.1150.jpg
#   inflating: train/dog/dog.1152.jpg
#   inflating: train/dog/dog.1154.jpg
#   inflating: train/dog/dog.1164.jpg
#   inflating: train/dog/dog.1202.jpg
#   inflating: train/dog/dog.1209.jpg
#   inflating: train/dog/dog.1218.jpg
#   inflating: train/dog/dog.1220.jpg
#   inflating: train/dog/dog.1222.jpg
#   inflating: train/dog/dog.1225.jpg
#   inflating: train/dog/dog.1238.jpg
#   inflating: train/dog/dog.1247.jpg
#   inflating: train/dog/dog.1274.jpg
#   inflating: train/dog/dog.1291.jpg
#   inflating: train/dog/dog.130.jpg
#   inflating: train/dog/dog.1300.jpg
#   inflating: train/dog/dog.1307.jpg
#   inflating: train/dog/dog.1311.jpg
#   inflating: train/dog/dog.1315.jpg
#   inflating: train/dog/dog.1319.jpg
#   inflating: train/dog/dog.1360.jpg
#   inflating: train/dog/dog.1367.jpg
#   inflating: train/dog/dog.1368.jpg
#   inflating: train/dog/dog.137.jpg
#   inflating: train/dog/dog.1376.jpg
#   inflating: train/dog/dog.1384.jpg
#   inflating: train/dog/dog.1400.jpg
#   inflating: train/dog/dog.1413.jpg
#   inflating: train/dog/dog.1421.jpg
#   inflating: train/dog/dog.1428.jpg
#   inflating: train/dog/dog.1435.jpg
#   inflating: train/dog/dog.1437.jpg
#   inflating: train/dog/dog.1453.jpg
#   inflating: train/dog/dog.1460.jpg
#   inflating: train/dog/dog.1479.jpg
#   inflating: train/dog/dog.1480.jpg
#   inflating: train/dog/dog.1494.jpg
#   inflating: train/dog/dog.1496.jpg
#   inflating: train/dog/dog.150.jpg
#   inflating: train/dog/dog.1507.jpg
#   inflating: train/dog/dog.1523.jpg
#   inflating: train/dog/dog.1549.jpg
#   inflating: train/dog/dog.155.jpg
#   inflating: train/dog/dog.1551.jpg
#   inflating: train/dog/dog.1572.jpg
#   inflating: train/dog/dog.1573.jpg
#   inflating: train/dog/dog.1588.jpg
#   inflating: train/dog/dog.1592.jpg
#   inflating: train/dog/dog.1595.jpg
#   inflating: train/dog/dog.1597.jpg
#   inflating: train/dog/dog.1607.jpg
#   inflating: train/dog/dog.1610.jpg
#   inflating: train/dog/dog.1618.jpg
#   inflating: train/dog/dog.1629.jpg
#   inflating: train/dog/dog.1642.jpg
#   inflating: train/dog/dog.1644.jpg
#   inflating: train/dog/dog.1649.jpg
#   inflating: train/dog/dog.165.jpg
#   inflating: train/dog/dog.1654.jpg
#   inflating: train/dog/dog.1662.jpg
#   inflating: train/dog/dog.1664.jpg
#   inflating: train/dog/dog.1678.jpg
#   inflating: train/dog/dog.1687.jpg
#   inflating: train/dog/dog.1714.jpg
#   inflating: train/dog/dog.1728.jpg
#   inflating: train/dog/dog.1740.jpg
#   inflating: train/dog/dog.1748.jpg
#   inflating: train/dog/dog.175.jpg
#   inflating: train/dog/dog.1750.jpg
#   inflating: train/dog/dog.1762.jpg
#   inflating: train/dog/dog.1771.jpg
#   inflating: train/dog/dog.18.jpg
#   inflating: train/dog/dog.1808.jpg
#   inflating: train/dog/dog.1824.jpg
#   inflating: train/dog/dog.1833.jpg
#   inflating: train/dog/dog.1842.jpg
#   inflating: train/dog/dog.1856.jpg
#   inflating: train/dog/dog.1871.jpg
#   inflating: train/dog/dog.189.jpg
#   inflating: train/dog/dog.1905.jpg
#   inflating: train/dog/dog.1910.jpg
#   inflating: train/dog/dog.1927.jpg
#   inflating: train/dog/dog.1937.jpg
#   inflating: train/dog/dog.194.jpg
#   inflating: train/dog/dog.1940.jpg
#   inflating: train/dog/dog.1946.jpg
#   inflating: train/dog/dog.1952.jpg
#   inflating: train/dog/dog.1976.jpg
#   inflating: train/dog/dog.1977.jpg
#   inflating: train/dog/dog.1989.jpg
#   inflating: train/dog/dog.200.jpg
#   inflating: train/dog/dog.2005.jpg
#   inflating: train/dog/dog.2015.jpg
#   inflating: train/dog/dog.203.jpg
#   inflating: train/dog/dog.2031.jpg
#   inflating: train/dog/dog.2081.jpg
#   inflating: train/dog/dog.2106.jpg
#   inflating: train/dog/dog.2108.jpg
#   inflating: train/dog/dog.2116.jpg
#   inflating: train/dog/dog.2118.jpg
#   inflating: train/dog/dog.2135.jpg
#   inflating: train/dog/dog.2141.jpg
#   inflating: train/dog/dog.2151.jpg
#   inflating: train/dog/dog.2155.jpg
#   inflating: train/dog/dog.2180.jpg
#   inflating: train/dog/dog.2194.jpg
#   inflating: train/dog/dog.2211.jpg
#   inflating: train/dog/dog.2218.jpg
#   inflating: train/dog/dog.2220.jpg
#   inflating: train/dog/dog.2226.jpg
#   inflating: train/dog/dog.2229.jpg
#   inflating: train/dog/dog.2257.jpg
#   inflating: train/dog/dog.2291.jpg
#   inflating: train/dog/dog.2293.jpg
#   inflating: train/dog/dog.2302.jpg
#   inflating: train/dog/dog.2320.jpg
#   inflating: train/dog/dog.2328.jpg
#   inflating: train/dog/dog.2350.jpg
#   inflating: train/dog/dog.2353.jpg
#   inflating: train/dog/dog.2354.jpg
#   inflating: train/dog/dog.2377.jpg
#   inflating: train/dog/dog.238.jpg
#   inflating: train/dog/dog.2391.jpg
#   inflating: train/dog/dog.24.jpg
#   inflating: train/dog/dog.2401.jpg
#   inflating: train/dog/dog.2404.jpg
#   inflating: train/dog/dog.2421.jpg
#   inflating: train/dog/dog.2429.jpg
#   inflating: train/dog/dog.2438.jpg
#   inflating: train/dog/dog.2451.jpg
#   inflating: train/dog/dog.2454.jpg
#   inflating: train/dog/dog.2467.jpg
#   inflating: train/dog/dog.2484.jpg
#   inflating: train/dog/dog.2485.jpg
#   inflating: train/dog/dog.2492.jpg
#   inflating: train/dog/dog.2512.jpg
#   inflating: train/dog/dog.2534.jpg
#   inflating: train/dog/dog.2536.jpg
#   inflating: train/dog/dog.2543.jpg
#   inflating: train/dog/dog.2551.jpg
#   inflating: train/dog/dog.2562.jpg
#   inflating: train/dog/dog.2568.jpg
#   inflating: train/dog/dog.2578.jpg
#   inflating: train/dog/dog.2593.jpg
#   inflating: train/dog/dog.2629.jpg
#   inflating: train/dog/dog.263.jpg
#   inflating: train/dog/dog.2632.jpg
#   inflating: train/dog/dog.2644.jpg
#   inflating: train/dog/dog.2667.jpg
#   inflating: train/dog/dog.2670.jpg
#   inflating: train/dog/dog.2678.jpg
#   inflating: train/dog/dog.2685.jpg
#   inflating: train/dog/dog.2692.jpg
#   inflating: train/dog/dog.2694.jpg
#   inflating: train/dog/dog.2699.jpg
#   inflating: train/dog/dog.272.jpg
#   inflating: train/dog/dog.2722.jpg
#   inflating: train/dog/dog.2739.jpg
#   inflating: train/dog/dog.2748.jpg
#   inflating: train/dog/dog.2750.jpg
#   inflating: train/dog/dog.2769.jpg
#   inflating: train/dog/dog.277.jpg
#   inflating: train/dog/dog.2779.jpg
#   inflating: train/dog/dog.2790.jpg
#   inflating: train/dog/dog.2791.jpg
#   inflating: train/dog/dog.2794.jpg
#   inflating: train/dog/dog.2796.jpg
#   inflating: train/dog/dog.2798.jpg
#   inflating: train/dog/dog.2800.jpg
#   inflating: train/dog/dog.2838.jpg
#   inflating: train/dog/dog.2847.jpg
#   inflating: train/dog/dog.2851.jpg
#   inflating: train/dog/dog.2854.jpg
#   inflating: train/dog/dog.2855.jpg
#   inflating: train/dog/dog.2863.jpg
#   inflating: train/dog/dog.2887.jpg
#   inflating: train/dog/dog.2890.jpg
#   inflating: train/dog/dog.2915.jpg
#   inflating: train/dog/dog.2920.jpg
#   inflating: train/dog/dog.2921.jpg
#   inflating: train/dog/dog.2927.jpg
#   inflating: train/dog/dog.2931.jpg
#   inflating: train/dog/dog.2934.jpg
#   inflating: train/dog/dog.2951.jpg
#   inflating: train/dog/dog.2969.jpg
#   inflating: train/dog/dog.2989.jpg
#   inflating: train/dog/dog.3013.jpg
#   inflating: train/dog/dog.3021.jpg
#   inflating: train/dog/dog.3022.jpg
#   inflating: train/dog/dog.3026.jpg
#   inflating: train/dog/dog.3034.jpg
#   inflating: train/dog/dog.3049.jpg
#   inflating: train/dog/dog.3054.jpg
#   inflating: train/dog/dog.3057.jpg
#   inflating: train/dog/dog.3061.jpg
#   inflating: train/dog/dog.3089.jpg
#   inflating: train/dog/dog.3104.jpg
#   inflating: train/dog/dog.3106.jpg
#   inflating: train/dog/dog.3111.jpg
#   inflating: train/dog/dog.3115.jpg
#   inflating: train/dog/dog.3127.jpg
#   inflating: train/dog/dog.3129.jpg
#   inflating: train/dog/dog.3136.jpg
#   inflating: train/dog/dog.315.jpg
#   inflating: train/dog/dog.3153.jpg
#   inflating: train/dog/dog.3167.jpg
#   inflating: train/dog/dog.3168.jpg
#   inflating: train/dog/dog.3175.jpg
#   inflating: train/dog/dog.3195.jpg
#   inflating: train/dog/dog.320.jpg
#   inflating: train/dog/dog.3202.jpg
#   inflating: train/dog/dog.3215.jpg
#   inflating: train/dog/dog.323.jpg
#   inflating: train/dog/dog.3239.jpg
#   inflating: train/dog/dog.3240.jpg
#   inflating: train/dog/dog.3244.jpg
#   inflating: train/dog/dog.3256.jpg
#   inflating: train/dog/dog.3271.jpg
#   inflating: train/dog/dog.3272.jpg
#   inflating: train/dog/dog.3273.jpg
#   inflating: train/dog/dog.3279.jpg
#   inflating: train/dog/dog.3287.jpg
#   inflating: train/dog/dog.329.jpg
#   inflating: train/dog/dog.3299.jpg
#   inflating: train/dog/dog.3301.jpg
#   inflating: train/dog/dog.3304.jpg
#   inflating: train/dog/dog.3306.jpg
#   inflating: train/dog/dog.3311.jpg
#   inflating: train/dog/dog.3322.jpg
#   inflating: train/dog/dog.333.jpg
#   inflating: train/dog/dog.3345.jpg
#   inflating: train/dog/dog.3352.jpg
#   inflating: train/dog/dog.3354.jpg
#   inflating: train/dog/dog.3362.jpg
#   inflating: train/dog/dog.3363.jpg
#   inflating: train/dog/dog.3369.jpg
#   inflating: train/dog/dog.3374.jpg
#   inflating: train/dog/dog.3377.jpg
#   inflating: train/dog/dog.3386.jpg
#   inflating: train/dog/dog.339.jpg
#   inflating: train/dog/dog.3391.jpg
#   inflating: train/dog/dog.3398.jpg
#   inflating: train/dog/dog.3401.jpg
#   inflating: train/dog/dog.3403.jpg
#   inflating: train/dog/dog.3404.jpg
#   inflating: train/dog/dog.3411.jpg
#   inflating: train/dog/dog.3414.jpg
#   inflating: train/dog/dog.3416.jpg
#   inflating: train/dog/dog.3418.jpg
#   inflating: train/dog/dog.3431.jpg
#   inflating: train/dog/dog.3445.jpg
#   inflating: train/dog/dog.3455.jpg
#   inflating: train/dog/dog.346.jpg
#   inflating: train/dog/dog.3484.jpg
#   inflating: train/dog/dog.349.jpg
#   inflating: train/dog/dog.3494.jpg
#   inflating: train/dog/dog.3496.jpg
#   inflating: train/dog/dog.3498.jpg
#   inflating: train/dog/dog.350.jpg
#   inflating: train/dog/dog.3511.jpg
#   inflating: train/dog/dog.3512.jpg
#   inflating: train/dog/dog.3516.jpg
#   inflating: train/dog/dog.3532.jpg
#   inflating: train/dog/dog.3534.jpg
#   inflating: train/dog/dog.3544.jpg
#   inflating: train/dog/dog.3591.jpg
#   inflating: train/dog/dog.3594.jpg
#   inflating: train/dog/dog.36.jpg
#   inflating: train/dog/dog.3603.jpg
#   inflating: train/dog/dog.3604.jpg
#   inflating: train/dog/dog.3607.jpg
#   inflating: train/dog/dog.3610.jpg
#   inflating: train/dog/dog.3616.jpg
#   inflating: train/dog/dog.362.jpg
#   inflating: train/dog/dog.3627.jpg
#   inflating: train/dog/dog.3649.jpg
#   inflating: train/dog/dog.3687.jpg
#   inflating: train/dog/dog.3729.jpg
#   inflating: train/dog/dog.3752.jpg
#   inflating: train/dog/dog.3755.jpg
#   inflating: train/dog/dog.3757.jpg
#   inflating: train/dog/dog.3767.jpg
#   inflating: train/dog/dog.3768.jpg
#   inflating: train/dog/dog.378.jpg
#   inflating: train/dog/dog.3783.jpg
#   inflating: train/dog/dog.3784.jpg
#   inflating: train/dog/dog.3786.jpg
#   inflating: train/dog/dog.380.jpg
#   inflating: train/dog/dog.3813.jpg
#   inflating: train/dog/dog.3821.jpg
#   inflating: train/dog/dog.3849.jpg
#   inflating: train/dog/dog.3851.jpg
#   inflating: train/dog/dog.3852.jpg
#   inflating: train/dog/dog.3870.jpg
#   inflating: train/dog/dog.3880.jpg
#   inflating: train/dog/dog.3905.jpg
#   inflating: train/dog/dog.3937.jpg
#   inflating: train/dog/dog.3940.jpg
#   inflating: train/dog/dog.3946.jpg
#   inflating: train/dog/dog.3959.jpg
#   inflating: train/dog/dog.3966.jpg
#   inflating: train/dog/dog.3967.jpg
#   inflating: train/dog/dog.3974.jpg
#   inflating: train/dog/dog.3980.jpg
#   inflating: train/dog/dog.3988.jpg
#   inflating: train/dog/dog.3996.jpg
#   inflating: train/dog/dog.4.jpg
#   inflating: train/dog/dog.4000.jpg
#   inflating: train/dog/dog.4034.jpg
#   inflating: train/dog/dog.4036.jpg
#   inflating: train/dog/dog.4049.jpg
#   inflating: train/dog/dog.4059.jpg
#   inflating: train/dog/dog.406.jpg
#   inflating: train/dog/dog.4064.jpg
#   inflating: train/dog/dog.4066.jpg
#   inflating: train/dog/dog.4073.jpg
#   inflating: train/dog/dog.4084.jpg
#   inflating: train/dog/dog.4085.jpg
#   inflating: train/dog/dog.4086.jpg
#   inflating: train/dog/dog.409.jpg
#   inflating: train/dog/dog.4098.jpg
#   inflating: train/dog/dog.4119.jpg
#   inflating: train/dog/dog.4122.jpg
#   inflating: train/dog/dog.4124.jpg
#   inflating: train/dog/dog.4125.jpg
#   inflating: train/dog/dog.4148.jpg
#   inflating: train/dog/dog.416.jpg
#   inflating: train/dog/dog.4163.jpg
#   inflating: train/dog/dog.4164.jpg
#   inflating: train/dog/dog.4168.jpg
#   inflating: train/dog/dog.4180.jpg
#   inflating: train/dog/dog.4181.jpg
#   inflating: train/dog/dog.4182.jpg
#   inflating: train/dog/dog.4185.jpg
#   inflating: train/dog/dog.4189.jpg
#   inflating: train/dog/dog.4196.jpg
#   inflating: train/dog/dog.4199.jpg
#   inflating: train/dog/dog.4205.jpg
#   inflating: train/dog/dog.4215.jpg
#   inflating: train/dog/dog.4228.jpg
#   inflating: train/dog/dog.4235.jpg
#   inflating: train/dog/dog.4236.jpg
#   inflating: train/dog/dog.4237.jpg
#   inflating: train/dog/dog.4245.jpg
#   inflating: train/dog/dog.4247.jpg
#   inflating: train/dog/dog.4251.jpg
#   inflating: train/dog/dog.4268.jpg
#   inflating: train/dog/dog.4300.jpg
#   inflating: train/dog/dog.4302.jpg
#   inflating: train/dog/dog.4310.jpg
#   inflating: train/dog/dog.4319.jpg
#   inflating: train/dog/dog.4321.jpg
#   inflating: train/dog/dog.4329.jpg
#   inflating: train/dog/dog.4337.jpg
#   inflating: train/dog/dog.4338.jpg
#   inflating: train/dog/dog.4339.jpg
#   inflating: train/dog/dog.4341.jpg
#   inflating: train/dog/dog.4344.jpg
#   inflating: train/dog/dog.4345.jpg
#   inflating: train/dog/dog.4351.jpg
#   inflating: train/dog/dog.4371.jpg
#   inflating: train/dog/dog.4372.jpg
#   inflating: train/dog/dog.4386.jpg
#   inflating: train/dog/dog.4388.jpg
#   inflating: train/dog/dog.4404.jpg
#   inflating: train/dog/dog.4413.jpg
#   inflating: train/dog/dog.4421.jpg
#   inflating: train/dog/dog.4456.jpg
#   inflating: train/dog/dog.4459.jpg
#   inflating: train/dog/dog.4467.jpg
#   inflating: train/dog/dog.4480.jpg
#   inflating: train/dog/dog.4484.jpg
#   inflating: train/dog/dog.4486.jpg
#   inflating: train/dog/dog.449.jpg
#   inflating: train/dog/dog.4492.jpg
#   inflating: train/dog/dog.4503.jpg
#   inflating: train/dog/dog.451.jpg
#   inflating: train/dog/dog.4510.jpg
#   inflating: train/dog/dog.4518.jpg
#   inflating: train/dog/dog.4525.jpg
#   inflating: train/dog/dog.4527.jpg
#   inflating: train/dog/dog.4530.jpg
#   inflating: train/dog/dog.4538.jpg
#   inflating: train/dog/dog.454.jpg
#   inflating: train/dog/dog.4541.jpg
#   inflating: train/dog/dog.4552.jpg
#   inflating: train/dog/dog.4565.jpg
#   inflating: train/dog/dog.4569.jpg
#   inflating: train/dog/dog.4570.jpg
#   inflating: train/dog/dog.4592.jpg
#   inflating: train/dog/dog.4606.jpg
#   inflating: train/dog/dog.461.jpg
#   inflating: train/dog/dog.4619.jpg
#   inflating: train/dog/dog.4620.jpg
#   inflating: train/dog/dog.4629.jpg
#   inflating: train/dog/dog.4630.jpg
#   inflating: train/dog/dog.4651.jpg
#   inflating: train/dog/dog.4655.jpg
#   inflating: train/dog/dog.4662.jpg
#   inflating: train/dog/dog.4663.jpg
#   inflating: train/dog/dog.4683.jpg
#   inflating: train/dog/dog.4684.jpg
#   inflating: train/dog/dog.4687.jpg
#   inflating: train/dog/dog.4689.jpg
#   inflating: train/dog/dog.4691.jpg
#   inflating: train/dog/dog.4693.jpg
#   inflating: train/dog/dog.4712.jpg
#   inflating: train/dog/dog.4719.jpg
#   inflating: train/dog/dog.4746.jpg
#   inflating: train/dog/dog.4748.jpg
#   inflating: train/dog/dog.4767.jpg
#   inflating: train/dog/dog.4768.jpg
#   inflating: train/dog/dog.4781.jpg
#   inflating: train/dog/dog.4784.jpg
#   inflating: train/dog/dog.4801.jpg
#   inflating: train/dog/dog.4803.jpg
#   inflating: train/dog/dog.481.jpg
#   inflating: train/dog/dog.4826.jpg
#   inflating: train/dog/dog.4830.jpg
#   inflating: train/dog/dog.4843.jpg
#   inflating: train/dog/dog.4848.jpg
#   inflating: train/dog/dog.4861.jpg
#   inflating: train/dog/dog.4863.jpg
#   inflating: train/dog/dog.4865.jpg
#   inflating: train/dog/dog.4869.jpg
#   inflating: train/dog/dog.4873.jpg
#   inflating: train/dog/dog.4876.jpg
#   inflating: train/dog/dog.4882.jpg
#   inflating: train/dog/dog.4888.jpg
#   inflating: train/dog/dog.4893.jpg
#   inflating: train/dog/dog.4905.jpg
#   inflating: train/dog/dog.4908.jpg
#   inflating: train/dog/dog.4913.jpg
#   inflating: train/dog/dog.4914.jpg
#   inflating: train/dog/dog.4921.jpg
#   inflating: train/dog/dog.4923.jpg
#   inflating: train/dog/dog.4931.jpg
#   inflating: train/dog/dog.4962.jpg
#   inflating: train/dog/dog.4995.jpg
#   inflating: train/dog/dog.4996.jpg
#   inflating: train/dog/dog.5011.jpg
#   inflating: train/dog/dog.5014.jpg
#   inflating: train/dog/dog.5021.jpg
#   inflating: train/dog/dog.503.jpg
#   inflating: train/dog/dog.5035.jpg
#   inflating: train/dog/dog.5038.jpg
#   inflating: train/dog/dog.5040.jpg
#   inflating: train/dog/dog.5050.jpg
#   inflating: train/dog/dog.5065.jpg
#   inflating: train/dog/dog.5066.jpg
#   inflating: train/dog/dog.5071.jpg
#   inflating: train/dog/dog.509.jpg
#   inflating: train/dog/dog.5094.jpg
#   inflating: train/dog/dog.510.jpg
#   inflating: train/dog/dog.5101.jpg
#   inflating: train/dog/dog.511.jpg
#   inflating: train/dog/dog.5118.jpg
#   inflating: train/dog/dog.5124.jpg
#   inflating: train/dog/dog.5140.jpg
#   inflating: train/dog/dog.5149.jpg
#   inflating: train/dog/dog.5162.jpg
#   inflating: train/dog/dog.5173.jpg
#   inflating: train/dog/dog.518.jpg
#   inflating: train/dog/dog.5182.jpg
#   inflating: train/dog/dog.5187.jpg
#   inflating: train/dog/dog.5190.jpg
#   inflating: train/dog/dog.5199.jpg
#   inflating: train/dog/dog.5211.jpg
#   inflating: train/dog/dog.5213.jpg
#   inflating: train/dog/dog.522.jpg
#   inflating: train/dog/dog.5223.jpg
#   inflating: train/dog/dog.523.jpg
#   inflating: train/dog/dog.5234.jpg
#   inflating: train/dog/dog.5245.jpg
#   inflating: train/dog/dog.5269.jpg
#   inflating: train/dog/dog.5273.jpg
#   inflating: train/dog/dog.5295.jpg
#   inflating: train/dog/dog.5296.jpg
#   inflating: train/dog/dog.5305.jpg
#   inflating: train/dog/dog.5319.jpg
#   inflating: train/dog/dog.5327.jpg
#   inflating: train/dog/dog.5349.jpg
#   inflating: train/dog/dog.535.jpg
#   inflating: train/dog/dog.5350.jpg
#   inflating: train/dog/dog.536.jpg
#   inflating: train/dog/dog.5373.jpg
#   inflating: train/dog/dog.5390.jpg
#   inflating: train/dog/dog.5396.jpg
#   inflating: train/dog/dog.5415.jpg
#   inflating: train/dog/dog.5428.jpg
#   inflating: train/dog/dog.5452.jpg
#   inflating: train/dog/dog.5480.jpg
#   inflating: train/dog/dog.5487.jpg
#   inflating: train/dog/dog.5490.jpg
#   inflating: train/dog/dog.550.jpg
#   inflating: train/dog/dog.551.jpg
#   inflating: train/dog/dog.5514.jpg
#   inflating: train/dog/dog.5515.jpg
#   inflating: train/dog/dog.5521.jpg
#   inflating: train/dog/dog.5550.jpg
#   inflating: train/dog/dog.5554.jpg
#   inflating: train/dog/dog.5559.jpg
#   inflating: train/dog/dog.5568.jpg
#   inflating: train/dog/dog.5577.jpg
#   inflating: train/dog/dog.5590.jpg
#   inflating: train/dog/dog.5599.jpg
#   inflating: train/dog/dog.5617.jpg
#   inflating: train/dog/dog.5618.jpg
#   inflating: train/dog/dog.5621.jpg
#   inflating: train/dog/dog.5623.jpg
#   inflating: train/dog/dog.5664.jpg
#   inflating: train/dog/dog.5677.jpg
#   inflating: train/dog/dog.5683.jpg
#   inflating: train/dog/dog.5687.jpg
#   inflating: train/dog/dog.5689.jpg
#   inflating: train/dog/dog.570.jpg
#   inflating: train/dog/dog.5709.jpg
#   inflating: train/dog/dog.5730.jpg
#   inflating: train/dog/dog.5745.jpg
#   inflating: train/dog/dog.5749.jpg
#   inflating: train/dog/dog.5754.jpg
#   inflating: train/dog/dog.5767.jpg
#   inflating: train/dog/dog.5768.jpg
#   inflating: train/dog/dog.5769.jpg
#   inflating: train/dog/dog.5776.jpg
#   inflating: train/dog/dog.5802.jpg
#   inflating: train/dog/dog.5803.jpg
#   inflating: train/dog/dog.5805.jpg
#   inflating: train/dog/dog.581.jpg
#   inflating: train/dog/dog.5831.jpg
#   inflating: train/dog/dog.5849.jpg
#   inflating: train/dog/dog.585.jpg
#   inflating: train/dog/dog.5850.jpg
#   inflating: train/dog/dog.5860.jpg
#   inflating: train/dog/dog.5863.jpg
#   inflating: train/dog/dog.5878.jpg
#   inflating: train/dog/dog.5894.jpg
#   inflating: train/dog/dog.5905.jpg
#   inflating: train/dog/dog.5910.jpg
#   inflating: train/dog/dog.5924.jpg
#   inflating: train/dog/dog.5926.jpg
#   inflating: train/dog/dog.5944.jpg
#   inflating: train/dog/dog.5948.jpg
#   inflating: train/dog/dog.5953.jpg
#   inflating: train/dog/dog.5957.jpg
#   inflating: train/dog/dog.5967.jpg
#   inflating: train/dog/dog.5968.jpg
#   inflating: train/dog/dog.5970.jpg
#   inflating: train/dog/dog.5996.jpg
#   inflating: train/dog/dog.601.jpg
#   inflating: train/dog/dog.6035.jpg
#   inflating: train/dog/dog.6066.jpg
#   inflating: train/dog/dog.6074.jpg
#   inflating: train/dog/dog.6080.jpg
#   inflating: train/dog/dog.6098.jpg
#   inflating: train/dog/dog.6109.jpg
#   inflating: train/dog/dog.6117.jpg
#   inflating: train/dog/dog.6120.jpg
#   inflating: train/dog/dog.6130.jpg
#   inflating: train/dog/dog.6132.jpg
#   inflating: train/dog/dog.6134.jpg
#   inflating: train/dog/dog.614.jpg
#   inflating: train/dog/dog.6143.jpg
#   inflating: train/dog/dog.6144.jpg
#   inflating: train/dog/dog.6149.jpg
#   inflating: train/dog/dog.6150.jpg
#   inflating: train/dog/dog.6152.jpg
#   inflating: train/dog/dog.6173.jpg
#   inflating: train/dog/dog.6178.jpg
#   inflating: train/dog/dog.6183.jpg
#   inflating: train/dog/dog.6200.jpg
#   inflating: train/dog/dog.6206.jpg
#   inflating: train/dog/dog.6227.jpg
#   inflating: train/dog/dog.6231.jpg
#   inflating: train/dog/dog.6274.jpg
#   inflating: train/dog/dog.6291.jpg
#   inflating: train/dog/dog.630.jpg
#   inflating: train/dog/dog.6315.jpg
#   inflating: train/dog/dog.6327.jpg
#   inflating: train/dog/dog.6329.jpg
#   inflating: train/dog/dog.6334.jpg
#   inflating: train/dog/dog.6337.jpg
#   inflating: train/dog/dog.6340.jpg
#   inflating: train/dog/dog.6352.jpg
#   inflating: train/dog/dog.6357.jpg
#   inflating: train/dog/dog.6365.jpg
#   inflating: train/dog/dog.6367.jpg
#   inflating: train/dog/dog.637.jpg
#   inflating: train/dog/dog.6371.jpg
#   inflating: train/dog/dog.6377.jpg
#   inflating: train/dog/dog.6380.jpg
#   inflating: train/dog/dog.6382.jpg
#   inflating: train/dog/dog.6388.jpg
#   inflating: train/dog/dog.641.jpg
#   inflating: train/dog/dog.6419.jpg
#   inflating: train/dog/dog.6434.jpg
#   inflating: train/dog/dog.6452.jpg
#   inflating: train/dog/dog.6459.jpg
#   inflating: train/dog/dog.6489.jpg
#   inflating: train/dog/dog.6491.jpg
#   inflating: train/dog/dog.6495.jpg
#   inflating: train/dog/dog.6502.jpg
#   inflating: train/dog/dog.6510.jpg
#   inflating: train/dog/dog.6513.jpg
#   inflating: train/dog/dog.6514.jpg
#   inflating: train/dog/dog.6515.jpg
#   inflating: train/dog/dog.6523.jpg
#   inflating: train/dog/dog.6533.jpg
#   inflating: train/dog/dog.6537.jpg
#   inflating: train/dog/dog.6539.jpg
#   inflating: train/dog/dog.6549.jpg
#   inflating: train/dog/dog.6563.jpg
#   inflating: train/dog/dog.6564.jpg
#   inflating: train/dog/dog.6577.jpg
#   inflating: train/dog/dog.6580.jpg
#   inflating: train/dog/dog.66.jpg
#   inflating: train/dog/dog.6631.jpg
#   inflating: train/dog/dog.6673.jpg
#   inflating: train/dog/dog.6691.jpg
#   inflating: train/dog/dog.6712.jpg
#   inflating: train/dog/dog.6713.jpg
#   inflating: train/dog/dog.6741.jpg
#   inflating: train/dog/dog.6748.jpg
#   inflating: train/dog/dog.6756.jpg
#   inflating: train/dog/dog.6758.jpg
#   inflating: train/dog/dog.6765.jpg
#   inflating: train/dog/dog.6772.jpg
#   inflating: train/dog/dog.6786.jpg
#   inflating: train/dog/dog.68.jpg
#   inflating: train/dog/dog.6827.jpg
#   inflating: train/dog/dog.6829.jpg
#   inflating: train/dog/dog.683.jpg
#   inflating: train/dog/dog.6838.jpg
#   inflating: train/dog/dog.6858.jpg
#   inflating: train/dog/dog.6868.jpg
#   inflating: train/dog/dog.6879.jpg
#   inflating: train/dog/dog.6881.jpg
#   inflating: train/dog/dog.6912.jpg
#   inflating: train/dog/dog.6918.jpg
#   inflating: train/dog/dog.692.jpg
#   inflating: train/dog/dog.6925.jpg
#   inflating: train/dog/dog.6929.jpg
#   inflating: train/dog/dog.6955.jpg
#   inflating: train/dog/dog.6975.jpg
#   inflating: train/dog/dog.6978.jpg
#   inflating: train/dog/dog.6986.jpg
#   inflating: train/dog/dog.6993.jpg
#   inflating: train/dog/dog.7021.jpg
#   inflating: train/dog/dog.7023.jpg
#   inflating: train/dog/dog.7035.jpg
#   inflating: train/dog/dog.7039.jpg
#   inflating: train/dog/dog.7045.jpg
#   inflating: train/dog/dog.7053.jpg
#   inflating: train/dog/dog.7089.jpg
#   inflating: train/dog/dog.7093.jpg
#   inflating: train/dog/dog.7096.jpg
#   inflating: train/dog/dog.7098.jpg
#   inflating: train/dog/dog.7101.jpg
#   inflating: train/dog/dog.7106.jpg
#   inflating: train/dog/dog.7109.jpg
#   inflating: train/dog/dog.7130.jpg
#   inflating: train/dog/dog.7149.jpg
#   inflating: train/dog/dog.715.jpg
#   inflating: train/dog/dog.7150.jpg
#   inflating: train/dog/dog.7151.jpg
#   inflating: train/dog/dog.7160.jpg
#   inflating: train/dog/dog.7171.jpg
#   inflating: train/dog/dog.718.jpg
#   inflating: train/dog/dog.720.jpg
#   inflating: train/dog/dog.7207.jpg
#   inflating: train/dog/dog.7214.jpg
#   inflating: train/dog/dog.722.jpg
#   inflating: train/dog/dog.7241.jpg
#   inflating: train/dog/dog.7246.jpg
#   inflating: train/dog/dog.7252.jpg
#   inflating: train/dog/dog.7255.jpg
#   inflating: train/dog/dog.7261.jpg
#   inflating: train/dog/dog.7271.jpg
#   inflating: train/dog/dog.7285.jpg
#   inflating: train/dog/dog.7290.jpg
#   inflating: train/dog/dog.730.jpg
#   inflating: train/dog/dog.7310.jpg
#   inflating: train/dog/dog.7325.jpg
#   inflating: train/dog/dog.7329.jpg
#   inflating: train/dog/dog.7347.jpg
#   inflating: train/dog/dog.7352.jpg
#   inflating: train/dog/dog.737.jpg
#   inflating: train/dog/dog.7372.jpg
#   inflating: train/dog/dog.7373.jpg
#   inflating: train/dog/dog.7380.jpg
#   inflating: train/dog/dog.7388.jpg
#   inflating: train/dog/dog.739.jpg
#   inflating: train/dog/dog.7391.jpg
#   inflating: train/dog/dog.7397.jpg
#   inflating: train/dog/dog.74.jpg
#   inflating: train/dog/dog.7400.jpg
#   inflating: train/dog/dog.7402.jpg
#   inflating: train/dog/dog.7404.jpg
#   inflating: train/dog/dog.7409.jpg
#   inflating: train/dog/dog.7454.jpg
#   inflating: train/dog/dog.7514.jpg
#   inflating: train/dog/dog.7519.jpg
#   inflating: train/dog/dog.7523.jpg
#   inflating: train/dog/dog.7530.jpg
#   inflating: train/dog/dog.7531.jpg
#   inflating: train/dog/dog.7536.jpg
#   inflating: train/dog/dog.7538.jpg
#   inflating: train/dog/dog.7539.jpg
#   inflating: train/dog/dog.7545.jpg
#   inflating: train/dog/dog.7546.jpg
#   inflating: train/dog/dog.7549.jpg
#   inflating: train/dog/dog.7554.jpg
#   inflating: train/dog/dog.7558.jpg
#   inflating: train/dog/dog.7566.jpg
#   inflating: train/dog/dog.7577.jpg
#   inflating: train/dog/dog.7579.jpg
#   inflating: train/dog/dog.758.jpg
#   inflating: train/dog/dog.7580.jpg
#   inflating: train/dog/dog.7584.jpg
#   inflating: train/dog/dog.7585.jpg
#   inflating: train/dog/dog.761.jpg
#   inflating: train/dog/dog.7611.jpg
#   inflating: train/dog/dog.7630.jpg
#   inflating: train/dog/dog.7643.jpg
#   inflating: train/dog/dog.7648.jpg
#   inflating: train/dog/dog.7673.jpg
#   inflating: train/dog/dog.7679.jpg
#   inflating: train/dog/dog.7693.jpg
#   inflating: train/dog/dog.7702.jpg
#   inflating: train/dog/dog.7710.jpg
#   inflating: train/dog/dog.7713.jpg
#   inflating: train/dog/dog.7733.jpg
#   inflating: train/dog/dog.7741.jpg
#   inflating: train/dog/dog.7746.jpg
#   inflating: train/dog/dog.7749.jpg
#   inflating: train/dog/dog.7750.jpg
#   inflating: train/dog/dog.7763.jpg
#   inflating: train/dog/dog.7765.jpg
#   inflating: train/dog/dog.7775.jpg
#   inflating: train/dog/dog.7780.jpg
#   inflating: train/dog/dog.7798.jpg
#   inflating: train/dog/dog.7818.jpg
#   inflating: train/dog/dog.7819.jpg
#   inflating: train/dog/dog.783.jpg
#   inflating: train/dog/dog.7836.jpg
#   inflating: train/dog/dog.7840.jpg
#   inflating: train/dog/dog.7847.jpg
#   inflating: train/dog/dog.7848.jpg
#   inflating: train/dog/dog.7849.jpg
#   inflating: train/dog/dog.7870.jpg
#   inflating: train/dog/dog.790.jpg
#   inflating: train/dog/dog.7913.jpg
#   inflating: train/dog/dog.7916.jpg
#   inflating: train/dog/dog.7922.jpg
#   inflating: train/dog/dog.7930.jpg
#   inflating: train/dog/dog.7936.jpg
#   inflating: train/dog/dog.7955.jpg
#   inflating: train/dog/dog.796.jpg
#   inflating: train/dog/dog.7979.jpg
#   inflating: train/dog/dog.7995.jpg
#   inflating: train/dog/dog.7997.jpg
#   inflating: train/dog/dog.80.jpg
#   inflating: train/dog/dog.8015.jpg
#   inflating: train/dog/dog.8018.jpg
#   inflating: train/dog/dog.8020.jpg
#   inflating: train/dog/dog.8028.jpg
#   inflating: train/dog/dog.804.jpg
#   inflating: train/dog/dog.8041.jpg
#   inflating: train/dog/dog.8043.jpg
#   inflating: train/dog/dog.8047.jpg
#   inflating: train/dog/dog.8057.jpg
#   inflating: train/dog/dog.806.jpg
#   inflating: train/dog/dog.8060.jpg
#   inflating: train/dog/dog.8064.jpg
#   inflating: train/dog/dog.8071.jpg
#   inflating: train/dog/dog.8085.jpg
#   inflating: train/dog/dog.8102.jpg
#   inflating: train/dog/dog.8120.jpg
#   inflating: train/dog/dog.8126.jpg
#   inflating: train/dog/dog.815.jpg
#   inflating: train/dog/dog.8169.jpg
#   inflating: train/dog/dog.820.jpg
#   inflating: train/dog/dog.8224.jpg
#   inflating: train/dog/dog.8226.jpg
#   inflating: train/dog/dog.8227.jpg
#   inflating: train/dog/dog.8242.jpg
#   inflating: train/dog/dog.8258.jpg
#   inflating: train/dog/dog.8262.jpg
#   inflating: train/dog/dog.8268.jpg
#   inflating: train/dog/dog.8271.jpg
#   inflating: train/dog/dog.8288.jpg
#   inflating: train/dog/dog.8289.jpg
#   inflating: train/dog/dog.8297.jpg
#   inflating: train/dog/dog.8299.jpg
#   inflating: train/dog/dog.8309.jpg
#   inflating: train/dog/dog.8315.jpg
#   inflating: train/dog/dog.8316.jpg
#   inflating: train/dog/dog.8320.jpg
#   inflating: train/dog/dog.8324.jpg
#   inflating: train/dog/dog.8325.jpg
#   inflating: train/dog/dog.8327.jpg
#   inflating: train/dog/dog.8328.jpg
#   inflating: train/dog/dog.8330.jpg
#   inflating: train/dog/dog.8336.jpg
#   inflating: train/dog/dog.8343.jpg
#   inflating: train/dog/dog.8358.jpg
#   inflating: train/dog/dog.8359.jpg
#   inflating: train/dog/dog.8373.jpg
#   inflating: train/dog/dog.839.jpg
#   inflating: train/dog/dog.8409.jpg
#   inflating: train/dog/dog.8427.jpg
#   inflating: train/dog/dog.8431.jpg
#   inflating: train/dog/dog.8435.jpg
#   inflating: train/dog/dog.8452.jpg
#   inflating: train/dog/dog.8453.jpg
#   inflating: train/dog/dog.8458.jpg
#   inflating: train/dog/dog.8480.jpg
#   inflating: train/dog/dog.8491.jpg
#   inflating: train/dog/dog.8502.jpg
#   inflating: train/dog/dog.8504.jpg
#   inflating: train/dog/dog.8510.jpg
#   inflating: train/dog/dog.8511.jpg
#   inflating: train/dog/dog.8533.jpg
#   inflating: train/dog/dog.8543.jpg
#   inflating: train/dog/dog.8549.jpg
#   inflating: train/dog/dog.8558.jpg
#   inflating: train/dog/dog.8574.jpg
#   inflating: train/dog/dog.858.jpg
#   inflating: train/dog/dog.8589.jpg
#   inflating: train/dog/dog.8616.jpg
#   inflating: train/dog/dog.8618.jpg
#   inflating: train/dog/dog.8631.jpg
#   inflating: train/dog/dog.8651.jpg
#   inflating: train/dog/dog.8656.jpg
#   inflating: train/dog/dog.8660.jpg
#   inflating: train/dog/dog.8664.jpg
#   inflating: train/dog/dog.8669.jpg
#   inflating: train/dog/dog.8677.jpg
#   inflating: train/dog/dog.8682.jpg
#   inflating: train/dog/dog.869.jpg
#   inflating: train/dog/dog.8693.jpg
#   inflating: train/dog/dog.8694.jpg
#   inflating: train/dog/dog.8705.jpg
#   inflating: train/dog/dog.8708.jpg
#   inflating: train/dog/dog.8710.jpg
#   inflating: train/dog/dog.8719.jpg
#   inflating: train/dog/dog.8745.jpg
#   inflating: train/dog/dog.8746.jpg
#   inflating: train/dog/dog.8755.jpg
#   inflating: train/dog/dog.8769.jpg
#   inflating: train/dog/dog.8770.jpg
#   inflating: train/dog/dog.8774.jpg
#   inflating: train/dog/dog.8780.jpg
#   inflating: train/dog/dog.8788.jpg
#   inflating: train/dog/dog.8794.jpg
#   inflating: train/dog/dog.8800.jpg
#   inflating: train/dog/dog.8806.jpg
#   inflating: train/dog/dog.8810.jpg
#   inflating: train/dog/dog.8823.jpg
#   inflating: train/dog/dog.886.jpg
#   inflating: train/dog/dog.8864.jpg
#   inflating: train/dog/dog.8895.jpg
#   inflating: train/dog/dog.8909.jpg
#   inflating: train/dog/dog.8919.jpg
#   inflating: train/dog/dog.8930.jpg
#   inflating: train/dog/dog.8951.jpg
#   inflating: train/dog/dog.8955.jpg
#   inflating: train/dog/dog.8977.jpg
#   inflating: train/dog/dog.8995.jpg
#   inflating: train/dog/dog.8997.jpg
#   inflating: train/dog/dog.900.jpg
#   inflating: train/dog/dog.9005.jpg
#   inflating: train/dog/dog.9007.jpg
#   inflating: train/dog/dog.9012.jpg
#   inflating: train/dog/dog.9013.jpg
#   inflating: train/dog/dog.9042.jpg
#   inflating: train/dog/dog.905.jpg
#   inflating: train/dog/dog.9081.jpg
#   inflating: train/dog/dog.9098.jpg
#   inflating: train/dog/dog.911.jpg
#   inflating: train/dog/dog.9115.jpg
#   inflating: train/dog/dog.9117.jpg
#   inflating: train/dog/dog.9118.jpg
#   inflating: train/dog/dog.9130.jpg
#   inflating: train/dog/dog.9131.jpg
#   inflating: train/dog/dog.9134.jpg
#   inflating: train/dog/dog.9155.jpg
#   inflating: train/dog/dog.9167.jpg
#   inflating: train/dog/dog.9168.jpg
#   inflating: train/dog/dog.9181.jpg
#   inflating: train/dog/dog.9192.jpg
#   inflating: train/dog/dog.9202.jpg
#   inflating: train/dog/dog.9208.jpg
#   inflating: train/dog/dog.922.jpg
#   inflating: train/dog/dog.9238.jpg
#   inflating: train/dog/dog.9243.jpg
#   inflating: train/dog/dog.9255.jpg
#   inflating: train/dog/dog.9284.jpg
#   inflating: train/dog/dog.9288.jpg
#   inflating: train/dog/dog.9298.jpg
#   inflating: train/dog/dog.9303.jpg
#   inflating: train/dog/dog.9308.jpg
#   inflating: train/dog/dog.9324.jpg
#   inflating: train/dog/dog.9325.jpg
#   inflating: train/dog/dog.9340.jpg
#   inflating: train/dog/dog.9343.jpg
#   inflating: train/dog/dog.9346.jpg
#   inflating: train/dog/dog.9374.jpg
#   inflating: train/dog/dog.9388.jpg
#   inflating: train/dog/dog.9391.jpg
#   inflating: train/dog/dog.9396.jpg
#   inflating: train/dog/dog.9401.jpg
#   inflating: train/dog/dog.9425.jpg
#   inflating: train/dog/dog.9426.jpg
#   inflating: train/dog/dog.9430.jpg
#   inflating: train/dog/dog.9432.jpg
#   inflating: train/dog/dog.9437.jpg
#   inflating: train/dog/dog.9448.jpg
#   inflating: train/dog/dog.9499.jpg
#   inflating: train/dog/dog.9500.jpg
#   inflating: train/dog/dog.9511.jpg
#   inflating: train/dog/dog.9525.jpg
#   inflating: train/dog/dog.9537.jpg
#   inflating: train/dog/dog.9541.jpg
#   inflating: train/dog/dog.9543.jpg
#   inflating: train/dog/dog.9547.jpg
#   inflating: train/dog/dog.9550.jpg
#   inflating: train/dog/dog.9558.jpg
#   inflating: train/dog/dog.957.jpg
#   inflating: train/dog/dog.9572.jpg
#   inflating: train/dog/dog.9584.jpg
#   inflating: train/dog/dog.9591.jpg
#   inflating: train/dog/dog.9592.jpg
#   inflating: train/dog/dog.9597.jpg
#   inflating: train/dog/dog.9604.jpg
#   inflating: train/dog/dog.9615.jpg
#   inflating: train/dog/dog.9629.jpg
#   inflating: train/dog/dog.9634.jpg
#   inflating: train/dog/dog.9635.jpg
#   inflating: train/dog/dog.9642.jpg
#   inflating: train/dog/dog.9643.jpg
#   inflating: train/dog/dog.9650.jpg
#   inflating: train/dog/dog.9673.jpg
#   inflating: train/dog/dog.9674.jpg
#   inflating: train/dog/dog.9692.jpg
#   inflating: train/dog/dog.9695.jpg
#   inflating: train/dog/dog.9696.jpg
#   inflating: train/dog/dog.9697.jpg
#   inflating: train/dog/dog.9702.jpg
#   inflating: train/dog/dog.9713.jpg
#   inflating: train/dog/dog.9728.jpg
#   inflating: train/dog/dog.973.jpg
#   inflating: train/dog/dog.9733.jpg
#   inflating: train/dog/dog.9755.jpg
#   inflating: train/dog/dog.9764.jpg
#   inflating: train/dog/dog.9769.jpg
#   inflating: train/dog/dog.9771.jpg
#   inflating: train/dog/dog.9797.jpg
#   inflating: train/dog/dog.9808.jpg
#   inflating: train/dog/dog.9824.jpg
#   inflating: train/dog/dog.9827.jpg
#   inflating: train/dog/dog.984.jpg
#   inflating: train/dog/dog.9858.jpg
#   inflating: train/dog/dog.9859.jpg
#   inflating: train/dog/dog.9860.jpg
#   inflating: train/dog/dog.9873.jpg
#   inflating: train/dog/dog.988.jpg
#   inflating: train/dog/dog.9894.jpg
#   inflating: train/dog/dog.9915.jpg
#   inflating: train/dog/dog.9921.jpg
#   inflating: train/dog/dog.9922.jpg
#   inflating: train/dog/dog.9941.jpg
#   inflating: train/dog/dog.9942.jpg
#   inflating: train/dog/dog.9944.jpg
#   inflating: train/dog/dog.9951.jpg
#   inflating: train/dog/dog.9963.jpg
#   inflating: train/dog/dog.9975.jpg
#   inflating: train/dog/dog.998.jpg
#   inflating: train/dog/dog.9980.jpg
#   inflating: train/dog/dog.9982.jpg
#   inflating: train/dog/dog.9983.jpg
#   inflating: train/dog/dog.9985.jpg
#   inflating: train/dog/dog.100.jpg
#   inflating: train/dog/dog.1000.jpg
#   inflating: train/dog/dog.1006.jpg
#   inflating: train/dog/dog.101.jpg
#   inflating: train/dog/dog.1017.jpg
#   inflating: train/dog/dog.1019.jpg
#   inflating: train/dog/dog.1030.jpg
#   inflating: train/dog/dog.104.jpg
#   inflating: train/dog/dog.1052.jpg
#   inflating: train/dog/dog.1053.jpg
#   inflating: train/dog/dog.1056.jpg
#   inflating: train/dog/dog.1092.jpg
#   inflating: train/dog/dog.1105.jpg
#   inflating: train/dog/dog.1107.jpg
#   inflating: train/dog/dog.1110.jpg
#   inflating: train/dog/dog.1112.jpg
#   inflating: train/dog/dog.112.jpg
#   inflating: train/dog/dog.1123.jpg
#   inflating: train/dog/dog.1124.jpg
#   inflating: train/dog/dog.1177.jpg
#   inflating: train/dog/dog.1188.jpg
#   inflating: train/dog/dog.1196.jpg
#   inflating: train/dog/dog.1199.jpg
#   inflating: train/dog/dog.1224.jpg
#   inflating: train/dog/dog.1236.jpg
#   inflating: train/dog/dog.1245.jpg
#   inflating: train/dog/dog.1249.jpg
#   inflating: train/dog/dog.1262.jpg
#   inflating: train/dog/dog.1279.jpg
#   inflating: train/dog/dog.1285.jpg
#   inflating: train/dog/dog.1305.jpg
#   inflating: train/dog/dog.1306.jpg
#   inflating: train/dog/dog.1308.jpg
#   inflating: train/dog/dog.1310.jpg
#   inflating: train/dog/dog.1349.jpg
#   inflating: train/dog/dog.1350.jpg
#   inflating: train/dog/dog.1361.jpg
#   inflating: train/dog/dog.1381.jpg
#   inflating: train/dog/dog.1396.jpg
#   inflating: train/dog/dog.1398.jpg
#   inflating: train/dog/dog.1407.jpg
#   inflating: train/dog/dog.1408.jpg
#   inflating: train/dog/dog.1410.jpg
#   inflating: train/dog/dog.1425.jpg
#   inflating: train/dog/dog.1440.jpg
#   inflating: train/dog/dog.1445.jpg
#   inflating: train/dog/dog.1457.jpg
#   inflating: train/dog/dog.1492.jpg
#   inflating: train/dog/dog.1501.jpg
#   inflating: train/dog/dog.1527.jpg
#   inflating: train/dog/dog.1532.jpg
#   inflating: train/dog/dog.1555.jpg
#   inflating: train/dog/dog.1565.jpg
#   inflating: train/dog/dog.1569.jpg
#   inflating: train/dog/dog.1577.jpg
#   inflating: train/dog/dog.1583.jpg
#   inflating: train/dog/dog.159.jpg
#   inflating: train/dog/dog.1593.jpg
# ...
#   inflating: validation/dog/dog.10653.jpg
#   inflating: validation/dog/dog.10654.jpg
#   inflating: validation/dog/dog.10662.jpg
#   inflating: validation/dog/dog.10666.jpg
#   inflating: validation/dog/dog.10680.jpg
#   inflating: validation/dog/dog.10684.jpg
#   inflating: validation/dog/dog.10697.jpg
#   inflating: validation/dog/dog.10704.jpg
#   inflating: validation/dog/dog.10710.jpg
#   inflating: validation/dog/dog.10717.jpg
#   inflating: validation/dog/dog.10719.jpg
#   inflating: validation/dog/dog.10724.jpg
#   inflating: validation/dog/dog.10727.jpg
#   inflating: validation/dog/dog.10730.jpg
#   inflating: validation/dog/dog.10734.jpg
#   inflating: validation/dog/dog.10738.jpg
#   inflating: validation/dog/dog.10739.jpg
#   inflating: validation/dog/dog.10741.jpg
#   inflating: validation/dog/dog.10747.jpg
#   inflating: validation/dog/dog.10750.jpg
#   inflating: validation/dog/dog.10752.jpg
#   inflating: validation/dog/dog.10754.jpg
#   inflating: validation/dog/dog.10761.jpg
#   inflating: validation/dog/dog.10769.jpg
#   inflating: validation/dog/dog.10773.jpg
#   inflating: validation/dog/dog.10784.jpg
#   inflating: validation/dog/dog.10785.jpg
#   inflating: validation/dog/dog.10789.jpg
#   inflating: validation/dog/dog.10803.jpg
#   inflating: validation/dog/dog.10808.jpg
#   inflating: validation/dog/dog.10813.jpg
#   inflating: validation/dog/dog.10815.jpg
#   inflating: validation/dog/dog.10820.jpg
#   inflating: validation/dog/dog.10831.jpg
#   inflating: validation/dog/dog.10837.jpg
#   inflating: validation/dog/dog.10844.jpg
#   inflating: validation/dog/dog.10845.jpg
#   inflating: validation/dog/dog.10846.jpg
#   inflating: validation/dog/dog.10848.jpg
#   inflating: validation/dog/dog.10853.jpg
#   inflating: validation/dog/dog.10861.jpg
#   inflating: validation/dog/dog.10862.jpg
#   inflating: validation/dog/dog.10864.jpg
#   inflating: validation/dog/dog.10872.jpg
#   inflating: validation/dog/dog.10873.jpg
#   inflating: validation/dog/dog.10874.jpg
#   inflating: validation/dog/dog.10892.jpg
#   inflating: validation/dog/dog.10893.jpg
#   inflating: validation/dog/dog.10897.jpg
#   inflating: validation/dog/dog.10903.jpg
#   inflating: validation/dog/dog.10904.jpg
#   inflating: validation/dog/dog.10908.jpg
#   inflating: validation/dog/dog.10911.jpg
#   inflating: validation/dog/dog.10922.jpg
#   inflating: validation/dog/dog.10926.jpg
#   inflating: validation/dog/dog.10929.jpg
#   inflating: validation/dog/dog.10937.jpg
#   inflating: validation/dog/dog.10949.jpg
#   inflating: validation/dog/dog.10959.jpg
#   inflating: validation/dog/dog.10961.jpg
#   inflating: validation/dog/dog.10974.jpg
#   inflating: validation/dog/dog.10980.jpg
#   inflating: validation/dog/dog.10982.jpg
#   inflating: validation/dog/dog.10987.jpg
#   inflating: validation/dog/dog.10991.jpg
#   inflating: validation/dog/dog.10992.jpg
#   inflating: validation/dog/dog.10994.jpg
#   inflating: validation/dog/dog.11000.jpg
#   inflating: validation/dog/dog.11003.jpg
#   inflating: validation/dog/dog.11009.jpg
#   inflating: validation/dog/dog.11010.jpg
#   inflating: validation/dog/dog.11012.jpg
#   inflating: validation/dog/dog.11013.jpg
#   inflating: validation/dog/dog.11019.jpg
#   inflating: validation/dog/dog.11020.jpg
#   inflating: validation/dog/dog.11025.jpg
#   inflating: validation/dog/dog.11028.jpg
#   inflating: validation/dog/dog.11030.jpg
#   inflating: validation/dog/dog.11040.jpg
#   inflating: validation/dog/dog.11046.jpg
#   inflating: validation/dog/dog.11052.jpg
#   inflating: validation/dog/dog.11055.jpg
#   inflating: validation/dog/dog.11060.jpg
#   inflating: validation/dog/dog.11061.jpg
#   inflating: validation/dog/dog.11065.jpg
#   inflating: validation/dog/dog.11079.jpg
#   inflating: validation/dog/dog.11084.jpg
#   inflating: validation/dog/dog.11086.jpg
#   inflating: validation/dog/dog.11092.jpg
#   inflating: validation/dog/dog.11094.jpg
#   inflating: validation/dog/dog.11104.jpg
#   inflating: validation/dog/dog.11105.jpg
#   inflating: validation/dog/dog.11112.jpg
#   inflating: validation/dog/dog.11114.jpg
#   inflating: validation/dog/dog.11118.jpg
#   inflating: validation/dog/dog.11120.jpg
#   inflating: validation/dog/dog.11135.jpg
#   inflating: validation/dog/dog.11145.jpg
#   inflating: validation/dog/dog.11146.jpg
#   inflating: validation/dog/dog.11147.jpg
#   inflating: validation/dog/dog.11148.jpg
#   inflating: validation/dog/dog.11159.jpg
#   inflating: validation/dog/dog.11162.jpg
#   inflating: validation/dog/dog.11165.jpg
#   inflating: validation/dog/dog.11168.jpg
#   inflating: validation/dog/dog.11171.jpg
#   inflating: validation/dog/dog.11180.jpg
#   inflating: validation/dog/dog.11181.jpg
#   inflating: validation/dog/dog.11184.jpg
#   inflating: validation/dog/dog.11198.jpg
#   inflating: validation/dog/dog.11200.jpg
#   inflating: validation/dog/dog.11204.jpg
#   inflating: validation/dog/dog.11205.jpg
#   inflating: validation/dog/dog.11210.jpg
#   inflating: validation/dog/dog.11214.jpg
#   inflating: validation/dog/dog.11226.jpg
#   inflating: validation/dog/dog.11232.jpg
#   inflating: validation/dog/dog.11243.jpg
#   inflating: validation/dog/dog.11245.jpg
#   inflating: validation/dog/dog.11246.jpg
#   inflating: validation/dog/dog.11249.jpg
#   inflating: validation/dog/dog.11258.jpg
#   inflating: validation/dog/dog.11269.jpg
#   inflating: validation/dog/dog.11278.jpg
#   inflating: validation/dog/dog.11286.jpg
#   inflating: validation/dog/dog.11288.jpg
#   inflating: validation/dog/dog.11295.jpg
#   inflating: validation/dog/dog.11298.jpg
#   inflating: validation/dog/dog.11302.jpg
#   inflating: validation/dog/dog.11303.jpg
#   inflating: validation/dog/dog.11306.jpg
#   inflating: validation/dog/dog.11314.jpg
#   inflating: validation/dog/dog.11318.jpg
#   inflating: validation/dog/dog.11320.jpg
#   inflating: validation/dog/dog.11333.jpg
#   inflating: validation/dog/dog.11337.jpg
#   inflating: validation/dog/dog.11349.jpg
#   inflating: validation/dog/dog.11350.jpg
#   inflating: validation/dog/dog.11354.jpg
#   inflating: validation/dog/dog.11363.jpg
#   inflating: validation/dog/dog.11376.jpg
#   inflating: validation/dog/dog.11378.jpg
#   inflating: validation/dog/dog.11381.jpg
#   inflating: validation/dog/dog.11391.jpg
#   inflating: validation/dog/dog.11398.jpg
#   inflating: validation/dog/dog.11406.jpg
#   inflating: validation/dog/dog.11409.jpg
#   inflating: validation/dog/dog.11411.jpg
#   inflating: validation/dog/dog.11417.jpg
#   inflating: validation/dog/dog.11419.jpg
#   inflating: validation/dog/dog.11422.jpg
#   inflating: validation/dog/dog.11430.jpg
#   inflating: validation/dog/dog.11431.jpg
#   inflating: validation/dog/dog.11432.jpg
#   inflating: validation/dog/dog.11435.jpg
#   inflating: validation/dog/dog.11438.jpg
#   inflating: validation/dog/dog.11448.jpg
#   inflating: validation/dog/dog.11452.jpg
#   inflating: validation/dog/dog.11459.jpg
#   inflating: validation/dog/dog.11467.jpg
#   inflating: validation/dog/dog.11468.jpg
#   inflating: validation/dog/dog.11471.jpg
#   inflating: validation/dog/dog.11472.jpg
#   inflating: validation/dog/dog.11474.jpg
#   inflating: validation/dog/dog.11481.jpg
#   inflating: validation/dog/dog.11485.jpg
#   inflating: validation/dog/dog.11486.jpg
#   inflating: validation/dog/dog.11498.jpg
#   inflating: validation/dog/dog.11504.jpg
#   inflating: validation/dog/dog.11505.jpg
#   inflating: validation/dog/dog.11506.jpg
#   inflating: validation/dog/dog.11508.jpg
#   inflating: validation/dog/dog.11512.jpg
#   inflating: validation/dog/dog.11516.jpg
#   inflating: validation/dog/dog.11519.jpg
#   inflating: validation/dog/dog.11539.jpg
#   inflating: validation/dog/dog.11544.jpg
#   inflating: validation/dog/dog.11545.jpg
#   inflating: validation/dog/dog.11551.jpg
#   inflating: validation/dog/dog.11566.jpg
#   inflating: validation/dog/dog.11567.jpg
#   inflating: validation/dog/dog.11572.jpg
#   inflating: validation/dog/dog.11575.jpg
#   inflating: validation/dog/dog.11576.jpg
#   inflating: validation/dog/dog.11603.jpg
#   inflating: validation/dog/dog.11611.jpg
#   inflating: validation/dog/dog.11618.jpg
#   inflating: validation/dog/dog.11638.jpg
#   inflating: validation/dog/dog.11641.jpg
#   inflating: validation/dog/dog.11650.jpg
#   inflating: validation/dog/dog.11655.jpg
#   inflating: validation/dog/dog.11657.jpg
#   inflating: validation/dog/dog.11664.jpg
#   inflating: validation/dog/dog.11667.jpg
#   inflating: validation/dog/dog.11670.jpg
#   inflating: validation/dog/dog.11678.jpg
#   inflating: validation/dog/dog.11680.jpg
#   inflating: validation/dog/dog.11698.jpg
#   inflating: validation/dog/dog.11708.jpg
#   inflating: validation/dog/dog.11714.jpg
#   inflating: validation/dog/dog.11715.jpg
#   inflating: validation/dog/dog.11718.jpg
#   inflating: validation/dog/dog.11719.jpg
#   inflating: validation/dog/dog.11721.jpg
#   inflating: validation/dog/dog.11724.jpg
#   inflating: validation/dog/dog.11731.jpg
#   inflating: validation/dog/dog.11738.jpg
#   inflating: validation/dog/dog.11741.jpg
#   inflating: validation/dog/dog.11743.jpg
#   inflating: validation/dog/dog.11749.jpg
#   inflating: validation/dog/dog.11750.jpg
#   inflating: validation/dog/dog.11751.jpg
#   inflating: validation/dog/dog.11762.jpg
#   inflating: validation/dog/dog.11772.jpg
#   inflating: validation/dog/dog.11781.jpg
#   inflating: validation/dog/dog.11786.jpg
#   inflating: validation/dog/dog.11789.jpg
#   inflating: validation/dog/dog.11793.jpg
#   inflating: validation/dog/dog.11799.jpg
#   inflating: validation/dog/dog.11800.jpg
#   inflating: validation/dog/dog.11807.jpg
#   inflating: validation/dog/dog.11809.jpg
#   inflating: validation/dog/dog.11817.jpg
#   inflating: validation/dog/dog.11819.jpg
#   inflating: validation/dog/dog.11824.jpg
#   inflating: validation/dog/dog.11825.jpg
#   inflating: validation/dog/dog.11827.jpg
#   inflating: validation/dog/dog.11831.jpg
#   inflating: validation/dog/dog.11833.jpg
#   inflating: validation/dog/dog.11839.jpg
#   inflating: validation/dog/dog.11844.jpg
#   inflating: validation/dog/dog.11853.jpg
#   inflating: validation/dog/dog.11857.jpg
#   inflating: validation/dog/dog.11859.jpg
#   inflating: validation/dog/dog.11863.jpg
#   inflating: validation/dog/dog.11865.jpg
#   inflating: validation/dog/dog.11866.jpg
#   inflating: validation/dog/dog.11884.jpg
#   inflating: validation/dog/dog.11887.jpg
#   inflating: validation/dog/dog.11894.jpg
#   inflating: validation/dog/dog.11895.jpg
#   inflating: validation/dog/dog.11925.jpg
#   inflating: validation/dog/dog.11929.jpg
#   inflating: validation/dog/dog.11935.jpg
#   inflating: validation/dog/dog.11937.jpg
#   inflating: validation/dog/dog.11939.jpg
#   inflating: validation/dog/dog.11942.jpg
#   inflating: validation/dog/dog.11943.jpg
#   inflating: validation/dog/dog.11963.jpg
#   inflating: validation/dog/dog.11965.jpg
#   inflating: validation/dog/dog.11966.jpg
#   inflating: validation/dog/dog.11968.jpg
#   inflating: validation/dog/dog.11970.jpg
#   inflating: validation/dog/dog.11975.jpg
#   inflating: validation/dog/dog.11983.jpg
#   inflating: validation/dog/dog.11986.jpg
#   inflating: validation/dog/dog.11995.jpg
#   inflating: validation/dog/dog.11998.jpg
#   inflating: validation/dog/dog.11999.jpg
#   inflating: validation/dog/dog.12001.jpg
#   inflating: validation/dog/dog.12019.jpg
#   inflating: validation/dog/dog.12020.jpg
#   inflating: validation/dog/dog.12023.jpg
#   inflating: validation/dog/dog.12029.jpg
#   inflating: validation/dog/dog.12032.jpg
#   inflating: validation/dog/dog.12033.jpg
#   inflating: validation/dog/dog.12041.jpg
#   inflating: validation/dog/dog.12046.jpg
#   inflating: validation/dog/dog.12066.jpg
#   inflating: validation/dog/dog.12067.jpg
#   inflating: validation/dog/dog.12073.jpg
#   inflating: validation/dog/dog.12074.jpg
#   inflating: validation/dog/dog.12076.jpg
#   inflating: validation/dog/dog.12079.jpg
#   inflating: validation/dog/dog.12082.jpg
#   inflating: validation/dog/dog.12084.jpg
#   inflating: validation/dog/dog.12086.jpg
#   inflating: validation/dog/dog.12088.jpg
#   inflating: validation/dog/dog.12089.jpg
#   inflating: validation/dog/dog.12094.jpg
#   inflating: validation/dog/dog.12106.jpg
#   inflating: validation/dog/dog.12111.jpg
#   inflating: validation/dog/dog.12116.jpg
#   inflating: validation/dog/dog.12117.jpg
#   inflating: validation/dog/dog.12122.jpg
#   inflating: validation/dog/dog.12125.jpg
#   inflating: validation/dog/dog.12147.jpg
#   inflating: validation/dog/dog.12152.jpg
#   inflating: validation/dog/dog.12162.jpg
#   inflating: validation/dog/dog.12164.jpg
#   inflating: validation/dog/dog.12169.jpg
#   inflating: validation/dog/dog.12171.jpg
#   inflating: validation/dog/dog.12174.jpg
#   inflating: validation/dog/dog.12176.jpg
#   inflating: validation/dog/dog.12179.jpg
#   inflating: validation/dog/dog.12180.jpg
#   inflating: validation/dog/dog.12186.jpg
#   inflating: validation/dog/dog.12188.jpg
#   inflating: validation/dog/dog.12196.jpg
#   inflating: validation/dog/dog.12198.jpg
#   inflating: validation/dog/dog.12205.jpg
#   inflating: validation/dog/dog.12208.jpg
#   inflating: validation/dog/dog.12211.jpg
#   inflating: validation/dog/dog.12221.jpg
#   inflating: validation/dog/dog.12223.jpg
#   inflating: validation/dog/dog.12224.jpg
#   inflating: validation/dog/dog.12230.jpg
#   inflating: validation/dog/dog.12237.jpg
#   inflating: validation/dog/dog.12239.jpg
#   inflating: validation/dog/dog.12240.jpg
#   inflating: validation/dog/dog.12241.jpg
#   inflating: validation/dog/dog.12252.jpg
#   inflating: validation/dog/dog.12253.jpg
#   inflating: validation/dog/dog.12254.jpg
#   inflating: validation/dog/dog.12257.jpg
#   inflating: validation/dog/dog.12259.jpg
#   inflating: validation/dog/dog.12265.jpg
#   inflating: validation/dog/dog.12273.jpg
#   inflating: validation/dog/dog.12280.jpg
#   inflating: validation/dog/dog.12281.jpg
#   inflating: validation/dog/dog.12283.jpg
#   inflating: validation/dog/dog.12290.jpg
#   inflating: validation/dog/dog.12294.jpg
#   inflating: validation/dog/dog.12295.jpg
#   inflating: validation/dog/dog.12296.jpg
#   inflating: validation/dog/dog.12301.jpg
#   inflating: validation/dog/dog.12309.jpg
#   inflating: validation/dog/dog.12315.jpg
#   inflating: validation/dog/dog.12317.jpg
#   inflating: validation/dog/dog.12323.jpg
#   inflating: validation/dog/dog.12326.jpg
#   inflating: validation/dog/dog.12347.jpg
#   inflating: validation/dog/dog.12362.jpg
#   inflating: validation/dog/dog.12363.jpg
#   inflating: validation/dog/dog.12368.jpg
#   inflating: validation/dog/dog.12380.jpg
#   inflating: validation/dog/dog.12385.jpg
#   inflating: validation/dog/dog.12391.jpg
#   inflating: validation/dog/dog.12392.jpg
#   inflating: validation/dog/dog.12409.jpg
#   inflating: validation/dog/dog.12410.jpg
#   inflating: validation/dog/dog.12415.jpg
#   inflating: validation/dog/dog.12417.jpg
#   inflating: validation/dog/dog.12420.jpg
#   inflating: validation/dog/dog.12427.jpg
#   inflating: validation/dog/dog.12429.jpg
#   inflating: validation/dog/dog.12435.jpg
#   inflating: validation/dog/dog.12436.jpg
#   inflating: validation/dog/dog.12437.jpg
#   inflating: validation/dog/dog.12448.jpg
#   inflating: validation/dog/dog.12458.jpg
#   inflating: validation/dog/dog.12460.jpg
#   inflating: validation/dog/dog.12464.jpg
#   inflating: validation/dog/dog.12470.jpg
#   inflating: validation/dog/dog.12472.jpg
#   inflating: validation/dog/dog.12473.jpg
#   inflating: validation/dog/dog.12475.jpg
#   inflating: validation/dog/dog.12480.jpg
#   inflating: validation/dog/dog.12483.jpg
#   inflating: validation/dog/dog.12484.jpg
#   inflating: validation/dog/dog.12485.jpg
#   inflating: validation/dog/dog.12486.jpg
#   inflating: validation/dog/dog.12495.jpg

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt

import torch
from torchvision import datasets, transforms

import helper

# %% [markdown]
# The easiest way to load image data is with `datasets.ImageFolder` from `torchvision` ([documentation](http://pytorch.org/docs/master/torchvision/datasets.html#imagefolder)). In general you'll use `ImageFolder` like so:
#
# ```python
# dataset = datasets.ImageFolder('path/to/data', transform=transform)
# ```
#
# where `'path/to/data'` is the file path to the data directory and `transform` is a list of processing steps built with the [`transforms`](http://pytorch.org/docs/master/torchvision/transforms.html) module from `torchvision`. ImageFolder expects the files and directories to be constructed like so:
# ```
# root/dog/xxx.png
# root/dog/xxy.png
# root/dog/xxz.png
#
# root/cat/123.png
# root/cat/nsdf3.png
# root/cat/asd932_.png
# ```
#
# where each class has it's own directory (`cat` and `dog`) for the images. The images are then labeled with the class taken from the directory name. So here, the image `123.png` would be loaded with the class label `cat`. You can download the dataset already structured like this [from here](https://s3.amazonaws.com/content.udacity-data.com/nd089/Cat_Dog_data.zip). I've also split it into a training set and test set.
#
# ### Transforms
#
# When you load in the data with `ImageFolder`, you'll need to define some transforms. For example, the images are different sizes but we'll need them to all be the same size for training. You can either resize them with `transforms.Resize()` or crop with `transforms.CenterCrop()`, `transforms.RandomResizedCrop()`, etc. We'll also need to convert the images to PyTorch tensors with `transforms.ToTensor()`. Typically you'll combine these transforms into a pipeline with `transforms.Compose()`, which accepts a list of transforms and runs them in sequence. It looks something like this to scale, then crop, then convert to a tensor:
#
# ```python
# transform = transforms.Compose([transforms.Resize(255),
#                                  transforms.CenterCrop(224),
#                                  transforms.ToTensor()])
#
# ```
#
# There are plenty of transforms available, I'll cover more in a bit and you can read through the [documentation](http://pytorch.org/docs/master/torchvision/transforms.html).
#
# ### Data Loaders
#
# With the `ImageFolder` loaded, you have to pass it to a [`DataLoader`](http://pytorch.org/docs/master/data.html#torch.utils.data.DataLoader). The `DataLoader` takes a dataset (such as you would get from `ImageFolder`) and returns batches of images and the corresponding labels. You can set various parameters like the batch size and if the data is shuffled after each epoch.
#
# ```python
# dataloader = torch.utils.data.DataLoader(dataset, batch_size=32, shuffle=True)
# ```
#
# Here `dataloader` is a [generator](https://jeffknupp.com/blog/2013/04/07/improve-your-python-yield-and-generators-explained/). To get data out of it, you need to loop through it or convert it to an iterator and call `next()`.
#
# ```python
# # Looping through it, get a batch on each loop
# for images, labels in dataloader:
#     pass
#
# # Get one batch
# images, labels = next(iter(dataloader))
# ```
#
# >**Exercise:** Load images from the `Cat_Dog_data/train` folder, define a few transforms, then build the dataloader.

# %%
data_dir = 'cats-and-dogs-data/train'

transform = transforms.Compose([transforms.Resize(255),
                                transforms.CenterCrop(224),
                                transforms.ToTensor()])
dataset = datasets.ImageFolder(data_dir, transform = transform)

dataloader = torch.utils.data.DataLoader(dataset, batch_size = 64, shuffle = True)

# %%
import myhelper as helper
# Run this to test your data loader
images, labels = next(iter(dataloader))
helper.imshow(images[0], normalize=False)

# %% [markdown]
# If you loaded the data correctly, you should see something like this (your image will be different):
#
# <img src='assets/cat_cropped.png' width=244>

# %% [markdown]
# ## Data Augmentation
#
# A common strategy for training neural networks is to introduce randomness in the input data itself. For example, you can randomly rotate, mirror, scale, and/or crop your images during training. This will help your network generalize as it's seeing the same images but in different locations, with different sizes, in different orientations, etc.
#
# To randomly rotate, scale and crop, then flip your images you would define your transforms like this:
#
# ```python
# train_transforms = transforms.Compose([transforms.RandomRotation(30),
#                                        transforms.RandomResizedCrop(224),
#                                        transforms.RandomHorizontalFlip(),
#                                        transforms.ToTensor(),
#                                        transforms.Normalize([0.5, 0.5, 0.5],
#                                                             [0.5, 0.5, 0.5])])
# ```
#
# You'll also typically want to normalize images with `transforms.Normalize`. You pass in a list of means and list of standard deviations, then the color channels are normalized like so
#
# ```input[channel] = (input[channel] - mean[channel]) / std[channel]```
#
# Subtracting `mean` centers the data around zero and dividing by `std` squishes the values to be between -1 and 1. Normalizing helps keep the network work weights near zero which in turn makes backpropagation more stable. Without normalization, networks will tend to fail to learn.
#
# You can find a list of all [the available transforms here](http://pytorch.org/docs/0.3.0/torchvision/transforms.html). When you're testing however, you'll want to use images that aren't altered (except you'll need to normalize the same way). So, for validation/test images, you'll typically just resize and crop.
#
# >**Exercise:** Define transforms for training data and testing data below. Leave off normalization for now.

# %%
data_dir = 'cats-and-dogs-data'

# TODO: Define transforms for the training data and testing data
train_transforms = transforms.Compose([transforms.RandomRotation(45),
                                       transforms.RandomResizedCrop(224),
                                       transforms.RandomHorizontalFlip(),
                                       transforms.ToTensor()])

test_transforms = transforms.Compose([ transforms.CenterCrop(224),
                                       transforms.Resize(255),
                                       transforms.ToTensor()])


# Pass transforms in here, then run the next cell to see how the transforms look
train_data = datasets.ImageFolder(data_dir + '/train', transform=train_transforms)
test_data = datasets.ImageFolder(data_dir + '/test', transform=test_transforms)

trainloader = torch.utils.data.DataLoader(train_data, batch_size=32)
testloader = torch.utils.data.DataLoader(test_data, batch_size=32)

# %%
# change this to the trainloader or testloader 
data_iter = iter(trainloader)

images, labels = next(data_iter)
fig, axes = plt.subplots(figsize=(10,4), ncols=4)
for ii in range(4):
    ax = axes[ii]
    helper.imshow(images[ii], ax=ax, normalize=False)

# %% [markdown]
# Your transformed images should look something like this.
#
# <center>Training examples:</center>
# <img src='assets/train_examples.png' width=500px>
#
# <center>Testing examples:</center>
# <img src='assets/test_examples.png' width=500px>

# %% [markdown]
# At this point you should be able to load data for training and testing. Now, you should try building a network that can classify cats vs dogs. This is quite a bit more complicated than before with the MNIST and Fashion-MNIST datasets. To be honest, you probably won't get it to work with a fully-connected network, no matter how deep. These images have three color channels and at a higher resolution (so far you've seen 28x28 images which are tiny).
#
# In the next part, I'll show you how to use a pre-trained network to build a model that can actually solve this problem.

# %%
# Optional TODO: Attempt to build a network to classify cats vs dogs from this dataset
